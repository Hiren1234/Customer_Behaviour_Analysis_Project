# %%
# Project Start I have stored the source file inside data directory
# EDA : Exploratory data analysis
import pandas as pd
# Import the data set
df = pd.read_csv(r"C:\Users\Hiren Patel\Desktop\Customer Behaviour Analysis\Customer_Behaviour_Analysis\data\customer_shopping_behavior.csv")
result = pd.DataFrame(df)
print(result)
len(result)
df.shape
# 5050 rows and 17 columns
print(result.describe())
# csv reads
# sql excel
# DataFrame
result.describe(include='all')
result.info()
result.isnull().sum()
# checks the null cell inside the dataset 569 601 and many more
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0            2701   22  Female        T-shirt     Clothing
# 1             521   51    Male     Sunglasses  Accessories
# 2            3157   18  Female          Shirt     Clothing
# 3            1687   22    Male         Gloves  Accessories
# 4            2929   40  Female        Jewelry  Accessories
# ...           ...  ...     ...            ...          ...
# 5045          913   24    Male         Hoodie     Clothing
# 5046         3466   19  Female       Backpack  Accessories
# 5047         3572   70  Female          Skirt     Clothing
# 5048         3195   43  Female       Sneakers     Footwear
# 5049         1832   62    Male         Blouse     Clothing
#
#       Purchase Amount (USD)        Location Size   Color  Season  \
# 0                      68.0      California   XL   Olive  Winter
# 1                      84.0  South Carolina    M   White  Spring
# ...

# %% [markdown]
# # DataCleaning

# %%
df.head()
# Out:
#    Customer ID  Age  Gender Item Purchased     Category  \
# 0         2701   22  Female        T-shirt     Clothing
# 1          521   51    Male     Sunglasses  Accessories
# 2         3157   18  Female          Shirt     Clothing
# 3         1687   22    Male         Gloves  Accessories
# 4         2929   40  Female        Jewelry  Accessories
#
#    Purchase Amount (USD)        Location Size   Color  Season  Review Rating  \
# 0                   68.0      California   XL   Olive  Winter            3.2
# 1                   84.0  South Carolina    M   White  Spring            3.9
# 2                   50.0         Montana    M   Black  Winter            3.1
# 3                   75.0        Illinois    L     Red    Fall            4.2
# 4                   80.0         Alabama    L  Yellow  Spring            3.6
#
#   Subscription Status   Shipping Type Discount Applied  Previous Purchases  \
# 0                  No        Standard               No                36.0
# ...

# %%
# df['Item Purchased'].unique()
# df.isnull().sum()
df.groupby('Category')['Item Purchased'].unique()
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df.groupby('Category')['Item Purchased'].unique()
correct_mapping ={
    #clothing
    "T-shirt" : "Clothing", "Short" : "Clothing", "Shocks" : "Clothing",
    "Hoddie" : "Clothing", "Pants" : "Clothing", "Socks" : "Clothing",
    "Jeans" : "Clothing", "Blouse" : "Clothing", "Skirts" : "Clothing",
    "Sweater" : "Clothing", "Dress" : "Clothing",

    # Accessories
    "Sunglasses" : "Accessories", "Gloves" : "Accessories",
    "Jewelry" : "Accessories" , "Hat" : "Accessories",
    "Handbag" : "Accessories", "Backpack" : "Accessories",
    "Belt" : "Accessories", "Scarf" : "Accessories",
    "Bag" : "Accessories",

    # Electronics
    "Laptop": "Electronics" ,"Phone" : "Electronics",
    "Headphones" : "Electronics", "Watch" : "Electronics",

    # Footwear
    "Shoes" : "Footwear", "Sandals" : "Footwear",
    "Sneakers" : "Footwear", "Boots": "Footwear",

    #Outwear
    "Coat" : "Outwear", "Jacket" : "Outwear"

}
correct_mapping
# Out:
# {'T-shirt': 'Clothing',
#  'Short': 'Clothing',
#  'Shocks': 'Clothing',
#  'Hoddie': 'Clothing',
#  'Pants': 'Clothing',
#  'Socks': 'Clothing',
#  'Jeans': 'Clothing',
#  'Blouse': 'Clothing',
#  'Skirts': 'Clothing',
#  'Sweater': 'Clothing',
#  'Dress': 'Clothing',
#  'Sunglasses': 'Accessories',
#  'Gloves': 'Accessories',
#  'Jewelry': 'Accessories',
#  'Hat': 'Accessories',
#  'Handbag': 'Accessories',
#  'Backpack': 'Accessories',
#  'Belt': 'Accessories',
#  'Scarf': 'Accessories',
#  'Bag': 'Accessories',
#  'Laptop': 'Electronics',
#  'Phone': 'Electronics',
#  'Headphones': 'Electronics',
#  'Watch': 'Electronics',
#  'Shoes': 'Footwear',
#  'Sandals': 'Footwear',
#  'Sneakers': 'Footwear',
#  'Boots': 'Footwear',
#  'Coat': 'Outwear',
#  'Jacket': 'Outwear'}

# %%
df['Category']=df['Item Purchased'].map(correct_mapping)

# %%
import pandas as pd

df.groupby('Category')['Item Purchased'].unique()
# Out:
# Category
# Accessories    [Sunglasses, Gloves, Jewelry, Hat, Handbag, Ba...
# Clothing       [T-shirt, Pants, Socks, Jeans, Blouse, Sweater...
# Electronics                   [Laptop, Phone, Watch, Headphones]
# Footwear                       [Shoes, Sandals, Sneakers, Boots]
# Outwear                                           [Coat, Jacket]
# Name: Item Purchased, dtype: object

# %%
# Checking the null values
df.isnull().sum()
# Checking the unique values
df['Size'].unique()
df.groupby('Category')['Size'].unique()
df.groupby('Item Purchased')['Size'].unique()
df.groupby('Category')['Item Purchased'].unique()
df.groupby('Category')['Size'].unique()

# to treat null values and replacing all values
df.loc[df['Category']=='Electronics', 'Size']= "Not Applicable"
df.groupby('Category')['Size'].unique()
df.groupby('Category')['Item Purchased'].unique()
df.groupby('Category')['Size'].unique()
# Trating null values and replacing all values
df.loc[df['Category']=='Accessories', 'Size']= "Free Size"
df.groupby('Category')['Size'].unique()
# Out:
# Category
# Accessories         [Free Size]
# Clothing          [XL, M, S, L]
# Electronics    [Not Applicable]
# Footwear          [M, L, S, XL]
# Outerwear         [XL, L, S, M]
# Name: Size, dtype: object
